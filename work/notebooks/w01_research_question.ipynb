# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/umarali8/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

print("My lane: Content refresh / SEO")

print("I want to study which pages may need a content refresh. I chose this lane because the dataset contains information about page age, recent updates, impressions, search position, CTR, and word count. These measurements may help identify pages that are worth reviewing and updating.")
# Out:
# My lane: Content refresh / SEO
# I want to study which pages may need a content refresh. I chose this lane because the dataset contains information about page age, recent updates, impressions, search position, CTR, and word count. These measurements may help identify pages that are worth reviewing and updating.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

print("My question:")

print("The decision is which pages should be prioritized for a content refresh. A content/SEO team would use the results to decide which pages to review first. A wrong recommendation could waste time and resources updating a page that does not need an update, or cause the team to miss a page that could benefit from a refresh. My goal is to provide decision-support, not an automatic final decision.")
# Out:
# My question:
# The decision is which pages should be prioritized for a content refresh. A content/SEO team would use the results to decide which pages to review first. A wrong recommendation could waste time and resources updating a page that does not need an update, or cause the team to miss a page that could benefit from a refresh. My goal is to provide decision-support, not an automatic final decision.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.


import pandas as pd

# Load dataset
df = pd.read_csv("/content/sample_data/content_refresh_anonymized.csv")

# Dataset shape
print("Dataset Shape:")
print(df.shape)

# Column names
print("\nColumns:")
print(df.columns.tolist())

# First 5 rows
print("\nFirst 5 Rows:")
display(df.head())

# Summary statistics
print("\nSummary:")
display(df.describe(include="all"))
# Out:
# Dataset Shape:
# (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#
# First 5 Rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

print("What I can and can't claim:")

print("I can describe patterns that are observed and measured in this dataset and use them to provide directional decision-support about which pages may be worth reviewing. I can compare pages and identify features that are associated with the outcome in this dataset.")

print("I cannot claim that these results prove that changing a page will cause its performance to improve. I cannot claim that the model predicts Google's actions or ranking decisions. The results are decision-support and should be checked with appropriate validation before being used in practice.")
# Out:
# What I can and can't claim:
# I can describe patterns that are observed and measured in this dataset and use them to provide directional decision-support about which pages may be worth reviewing. I can compare pages and identify features that are associated with the outcome in this dataset.
# I cannot claim that these results prove that changing a page will cause its performance to improve. I cannot claim that the model predicts Google's actions or ranking decisions. The results are decision-support and should be checked with appropriate validation before being used in practice.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
