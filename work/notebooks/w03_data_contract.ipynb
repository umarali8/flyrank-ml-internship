# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/umarali8/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# 1. Unit of analysis + time window

unit_of_analysis = "One row represents one webpage (URL) in one month."
time_window = "March 2026"

print("Unit of Analysis:", unit_of_analysis)
print("Time Window:", time_window)
# Out:
# Unit of Analysis: One row represents one webpage (URL) in one month.
# Time Window: March 2026

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# 2. Fields: feature / label / context / excluded

feature = [
    "Clicks",
    "Impressions",
    "CTR",
    "Average Position",
    "Page URL"
]

label = "Content Refresh Priority Score (Ranking)"

context = [
    "Month (March 2026)",
    "Search Performance Data"
]

excluded = {
    "Future Clicks": "Not available at decision time (would cause data leakage)."
}

print("Features:")
for f in feature:
    print("-", f)

print("\nLabel:")
print(label)

print("\nContext:")
for c in context:
    print("-", c)

print("\nExcluded:")
for k, v in excluded.items():
    print(f"- {k}: {v}")
# Out:
# Features:
# - Clicks
# - Impressions
# - CTR
# - Average Position
# - Page URL
#
# Label:
# Content Refresh Priority Score (Ranking)
#
# Context:
# - Month (March 2026)
# - Search Performance Data
#
# Excluded:
# - Future Clicks: Not available at decision time (would cause data leakage).

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# 3. Verify it with queries (grain, counts, windows)

# Example verification queries for March 2026 data

print("Query 1: Grain check")
print("One row represents one webpage (URL) for one month.")

print("\nQuery 2: Row count and date window")
month = "2026-03"
print("Selected month:", month)
print("Row count: Verify using warehouse query output")

print("\nQuery 3: Availability check")
print("Filter condition: IS TRUE")
print("Available rows are counted after applying availability filter.")
# Out:
# Query 1: Grain check
# One row represents one webpage (URL) for one month.
#
# Query 2: Row count and date window
# Selected month: 2026-03
# Row count: Verify using warehouse query output
#
# Query 3: Availability check
# Filter condition: IS TRUE
# Available rows are counted after applying availability filter.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# 4. Data limits

limitations = [
    "This dataset only contains historical search performance data.",
    "It cannot guarantee why a page performed well or poorly.",
    "External factors such as algorithm updates or seasonality are not fully captured.",
    "The model should support decisions, not replace human judgment."
]

print("Data Limitations:\n")

for i, item in enumerate(limitations, 1):
    print(f"{i}. {item}")
# Out:
# Data Limitations:
#
# 1. This dataset only contains historical search performance data.
# 2. It cannot guarantee why a page performed well or poorly.
# 3. External factors such as algorithm updates or seasonality are not fully captured.
# 4. The model should support decisions, not replace human judgment.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
