# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/umarali8/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

from IPython.display import Markdown, display

display(Markdown("""
### My Lane as an ML Task

**Chosen Lane:** Content Refresh Prioritization

**ML Task Type:** Ranking (Scoring)

This task ranks website pages based on how urgently they should be refreshed. Pages with higher priority scores should be updated first because they are expected to have the greatest impact on search performance and user engagement.
"""))
# Out:
# ### My Lane as an ML Task
#
# **Chosen Lane:** Content Refresh Prioritization
#
# **ML Task Type:** Ranking (Scoring)
#
# This task ranks website pages based on how urgently they should be refreshed. Pages with higher priority scores should be updated first because they are expected to have the greatest impact on search performance and user engagement.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.


from IPython.display import Markdown, display

display(Markdown("""
### Target or Proxy

**Target:** Refresh Priority Score

The model predicts a refresh priority score for each webpage.

If a true priority label is not available, a proxy can be created using signals such as:
- Low organic traffic
- Declining clicks
- Old content age
- Low engagement
- Poor search ranking

Pages with these characteristics receive a higher refresh priority.
"""))
# Out:
# ### Target or Proxy
#
# **Target:** Refresh Priority Score
#
# The model predicts a refresh priority score for each webpage.
#
# If a true priority label is not available, a proxy can be created using signals such as:
# - Low organic traffic
# - Declining clicks
# - Old content age
# - Low engagement
# - Poor search ranking
#
# Pages with these characteristics receive a higher refresh priority.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.


from IPython.display import Markdown, display

display(Markdown("""
### Success Metric

**Success Metric:** NDCG (Normalized Discounted Cumulative Gain)

The model is successful if it ranks the most important pages at the top of the list.

A higher NDCG score means the model correctly prioritizes pages that should be refreshed first. This helps content teams focus on updates that are likely to have the greatest impact.
"""))
# Out:
# ### Success Metric
#
# **Success Metric:** NDCG (Normalized Discounted Cumulative Gain)
#
# The model is successful if it ranks the most important pages at the top of the list.
#
# A higher NDCG score means the model correctly prioritizes pages that should be refreshed first. This helps content teams focus on updates that are likely to have the greatest impact.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.


from IPython.display import Markdown, display
import pandas as pd

# Sample dataframe
df = pd.DataFrame({
    "page_url": [
        "/blog/seo-guide",
        "/blog/ai-tools",
        "/services/web-development"
    ],
    "organic_traffic": [1200, 450, 800],
    "clicks": [300, 90, 180],
    "content_age_months": [18, 24, 8]
})

display(df)

display(Markdown("""
### Unit of Analysis

Each row in this dataframe represents **one webpage**. The model will assign a refresh priority score to each page based on its performance metrics.
"""))
# Out:
#                     page_url  organic_traffic  clicks  content_age_months
# 0            /blog/seo-guide             1200     300                  18
# 1             /blog/ai-tools              450      90                  24
# 2  /services/web-development              800     180                   8
# ### Unit of Analysis
#
# Each row in this dataframe represents **one webpage**. The model will assign a refresh priority score to each page based on its performance metrics.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

from IPython.display import Markdown, display

display(Markdown("""
### Why ML Beats a Fixed Rule

A fixed rule cannot consider many factors together.

Machine learning can learn patterns from multiple signals such as traffic, clicks, content age, rankings, and engagement.

This makes predictions more accurate and helps prioritize the pages that need refreshing the most.
"""))
# Out:
# ### Why ML Beats a Fixed Rule
#
# A fixed rule cannot consider many factors together.
#
# Machine learning can learn patterns from multiple signals such as traffic, clicks, content age, rankings, and engagement.
#
# This makes predictions more accurate and helps prioritize the pages that need refreshing the most.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
