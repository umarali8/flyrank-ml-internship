# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/umarali8/flyrank-ml-internship/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %%
rule = """
Action: Refresh Content

Rule:
If a page is older than 365 days and its CTR is below 2%,
give it a high baseline score because it is likely outdated
and not attracting enough clicks.

Reason Codes:
- STALE_CONTENT
- LOW_CTR
"""
print(rule)
# Out:
# Action: Refresh Content
#
# Rule:
# If a page is older than 365 days and its CTR is below 2%,
# give it a high baseline score because it is likely outdated
# and not attracting enough clicks.
#
# Reason Codes:
# - STALE_CONTENT
# - LOW_CTR

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %%
import pandas as pd
import os

# Load dataset
df = pd.read_csv("/content/content_refresh_anonymized.csv")

# Baseline Score
df["baseline_score"] = 0

# Rule 1: Old content
df.loc[df["content_age_days"] > 365, "baseline_score"] += 50

# Rule 2: Low CTR
df.loc[df["ctr"] < 2, "baseline_score"] += 50

# Reason Code
df["reason_code"] = "STALE_LOW_CTR"

# Action
df["action"] = "Refresh Content"

# Rank
ranked = df.sort_values("baseline_score", ascending=False)

# Save CSV
os.makedirs("work/outputs", exist_ok=True)

ranked.to_csv(
    "work/outputs/baseline_action_score.csv",
    index=False
)

print(ranked.head(10))
print("\nCSV saved successfully!")
# Out:
#                  content_id          client_id  search_volume  competition  \
# 29980  content_81a91fe32bc2  client_e629fa6598          210.0         0.00
# 31     content_24ee79621dbf  client_19581e27de           50.0         0.09
# 30     content_249298388b45  client_2c624232cd          590.0         0.00
# 27     content_7ea135180dd9  client_4ec9599fc2           10.0         0.32
# 23     content_2da6ae9d0882  client_e629fa6598            0.0         0.00
# 17     content_761a44afda12  client_19581e27de           10.0         0.00
# 29967  content_b9e02bd01a73  client_2c624232cd            0.0         0.00
# 29964  content_07ea0872b973  client_2c624232cd            0.0         0.00
# 29963  content_7ba9b154acf6  client_19581e27de          170.0         0.16
# 29953  content_ac21791a5807  client_19581e27de          720.0         0.20
#
#       competition_level    cpc     content_type    main_intent  word_count  \
# 29980               LOW   0.00  keyword article  informational         NaN
# 31                  LOW   0.00  keyword article  informational         NaN
# 30                  LOW   0.00  keyword article  informational         NaN
# 27                  LOW  10.57  keyword article  informational         NaN
# 23                  LOW   0.00  keyword article  informational         NaN
# 17                  LOW   0.00  keyword article  transactional         NaN
# 29967               LOW   0.00  keyword article  informational      2646.0
# 29964               LOW   0.00  keyword article  informational         NaN
# 29963               LOW   2.75  keyword article  informational         NaN
# 29953               LOW   0.05  keyword article  informational         NaN
#
#        char_count  ... engagement_rate scroll_rate  ai_traffic_pct  \
# 29980         NaN  ...            0.00        8.33             0.0
# 31            NaN  ...            0.00        0.00             0.0
# 30            NaN  ...            0.00        0.00             0.0
# 27            NaN  ...            0.00        0.00             0.0
# 23            NaN  ...            0.00       25.00             0.0
# 17            NaN  ...           11.86       15.25             0.0
# 29967     17582.0  ...            0.00       40.00             0.0
# 29964         NaN  ...            7.69       42.86             0.0
# 29963         NaN  ...            0.00        0.00             0.0
# 29953         NaN  ...            0.00        0.00             0.0
#
#        impression_tier  position_tier  trend_direction  trend_pct  \
# 29980         moderate       striking           stable       15.8
# 31            moderate       page_3_5               up       42.5
# 30                 low           deep               up       46.7
# 27            moderate         page_1             down      -64.7
# 23                 low       striking             down     -100.0
# 17                good         page_1             down      -20.2
# 29967             good         page_1           stable        1.7
# 29964              low           deep           stable      -12.0
# 29963              low       page_3_5               up       90.9
# 29953         moderate         page_1             down      -27.8
#
#        baseline_score    reason_code           action
# 29980             100  STALE_LOW_CTR  Refresh Content
# 31                100  STALE_LOW_CTR  Refresh Content
# 30                100  STALE_LOW_CTR  Refresh Content
# 27                100  STALE_LOW_CTR  Refresh Content
# 23                100  STALE_LOW_CTR  Refresh Content
# 17                100  STALE_LOW_CTR  Refresh Content
# 29967             100  STALE_LOW_CTR  Refresh Content
# 29964             100  STALE_LOW_CTR  Refresh Content
# 29963             100  STALE_LOW_CTR  Refresh Content
# 29953             100  STALE_LOW_CTR  Refresh Content
#
# [10 rows x 47 columns]
#
# CSV saved successfully!

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %%
top20 = ranked.head(20)

for i, row in top20.iterrows():
    print(f"Rank {i+1}")
    print(f"Action: {row['action']}")
    print(f"Reason Code: {row['reason_code']}")
    print("Confidence: High")
    print("What would make it wrong? The page may be seasonal or already planned for an update.\n")
# Out:
# Rank 29981
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 32
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 31
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 28
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 24
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 18
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29968
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29965
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29964
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29954
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29953
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29949
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29936
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29930
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29929
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29925
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29924
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 34
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29906
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.
#
# Rank 29899
# Action: Refresh Content
# Reason Code: STALE_LOW_CTR
# Confidence: High
# What would make it wrong? The page may be seasonal or already planned for an update.

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %%
print("Weak Picks + Leakage Check\n")

print("Weak Picks:")
print("- Some pages may have temporary low CTR because of seasonal trends.")
print("- Older pages may still perform well and not require a refresh.")

print("\nLeakage Check:")
print("- No future clicks were used.")
print("- No future impressions were used.")
print("- No future labels or outcomes were used.")
print("- Only current available features were used to calculate the baseline score.")
# Out:
# Weak Picks + Leakage Check
#
# Weak Picks:
# - Some pages may have temporary low CTR because of seasonal trends.
# - Older pages may still perform well and not require a refresh.
#
# Leakage Check:
# - No future clicks were used.
# - No future impressions were used.
# - No future labels or outcomes were used.
# - Only current available features were used to calculate the baseline score.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
