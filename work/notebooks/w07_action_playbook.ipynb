# %% [markdown]
# # ML-10 — Content Action Playbook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/umarali8/flyrank-ml-internship/blob/main/work/notebooks/w07_action_playbook.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# *The queue: what to do first, and why, in words a human trusts.*

# %% [markdown]
# # Ranked Actions + Reason Codes
#
# **The queue:** what to do first, and why, in words a human trusts.
#
# | Priority | Recommended Action | Reason Code | Reason |
# |---:|---|---|---|
# | 1 | Refresh outdated content | RC-01 | Page is older than 365 days and may benefit from updated information. |
# | 2 | Improve title and meta description | RC-02 | Low CTR suggests the search snippet can be improved. |
# | 3 | Update target keywords | RC-03 | Ranking has declined and keywords may no longer match user intent. |
# | 4 | Review internal links | RC-04 | Better internal linking may improve page visibility. |
# | 5 | Monitor only | RC-05 | No immediate action is required; continue tracking performance. |

# %%
import pandas as pd

actions = pd.DataFrame({
    "Priority": [1, 2, 3, 4, 5],
    "Recommended Action": [
        "Refresh outdated content",
        "Improve title and meta description",
        "Update target keywords",
        "Review internal links",
        "Monitor only"
    ],
    "Reason Code": [
        "RC-01",
        "RC-02",
        "RC-03",
        "RC-04",
        "RC-05"
    ],
    "Reason": [
        "Page is older than 365 days and may benefit from updated information.",
        "Low CTR suggests the search snippet can be improved.",
        "Ranking has declined and keywords may no longer match user intent.",
        "Better internal linking may improve page visibility.",
        "No immediate action is required; continue monitoring."
    ]
})

actions
# Out:
#    Priority                  Recommended Action Reason Code  \
# 0         1            Refresh outdated content       RC-01
# 1         2  Improve title and meta description       RC-02
# 2         3              Update target keywords       RC-03
# 3         4               Review internal links       RC-04
# 4         5                        Monitor only       RC-05
#
#                                               Reason
# 0  Page is older than 365 days and may benefit fr...
# 1  Low CTR suggests the search snippet can be imp...
# 2  Ranking has declined and keywords may no longe...
# 3  Better internal linking may improve page visib...
# 4  No immediate action is required; continue moni...

# %% [markdown]
# ## 2. Intended use and limits
#
# *Who uses this, for what — and where it stops being valid.*

# %% [markdown]
# ### Intended Use
#
# This playbook is designed to support content teams by prioritizing pages that may benefit from content updates. It provides ranked recommendations based on observed patterns from the model and should be used as decision-support rather than automatic decision-making.
#
# ### Limits
#
# - The recommendations depend on the available dataset.
# - The model does not guarantee improved search performance.
# - Human review is required before making content changes.
# - The playbook is intended for educational purposes and is not a production system.

# %%
print("Intended Use")
print("- Supports content refresh prioritization.")
print("- Provides decision-support for content teams.")

print("\nLimits")
print("- Results depend on available data.")
print("- Human review is required.")
print("- Not intended for fully automated production use.")
# Out:
# Intended Use
# - Supports content refresh prioritization.
# - Provides decision-support for content teams.
#
# Limits
# - Results depend on available data.
# - Human review is required.
# - Not intended for fully automated production use.

# %% [markdown]
# ## 3. Human review + the no-go list
#
# *What a person must check before acting. What should never be automated.*

# %% [markdown]
# ### Human Review
#
# Before applying any recommendation, a content reviewer should verify:
#
# - The page content is still accurate.
# - The suggested update matches user intent.
# - No important information will be removed.
# - SEO changes are appropriate for the page.
#
# ### No-Go List
#
# The following actions should NOT be automated:
#
# - Publishing content without human approval.
# - Deleting pages automatically.
# - Changing important facts or statistics without verification.
# - Rewriting sensitive or legal content automatically.

# %%
print("Human Review Checklist")
print("- Verify content accuracy")
print("- Check user intent")
print("- Review SEO changes")
print("- Approve before publishing")

print("\nNo-Go List")
print("- No automatic publishing")
print("- No automatic page deletion")
print("- No automatic changes to legal or sensitive content")
# Out:
# Human Review Checklist
# - Verify content accuracy
# - Check user intent
# - Review SEO changes
# - Approve before publishing
#
# No-Go List
# - No automatic publishing
# - No automatic page deletion
# - No automatic changes to legal or sensitive content

# %% [markdown]
# ## 4. Monitoring / retrain triggers
#
# *What would tell you the recommendations went stale?*

# %% [markdown]
# ### Monitoring
#
# The model should be monitored regularly to ensure that its recommendations remain useful and relevant.
#
# ### Retrain Triggers
#
# The model should be retrained if:
#
# - A large amount of new data becomes available.
# - Search trends change significantly.
# - Model performance decreases over time.
# - New content categories are introduced.

# %%
print("Monitoring")
print("- Review model performance regularly.")
print("- Monitor search trends.")
print("- Track recommendation quality.")

print("\nRetrain Triggers")
print("- Large amount of new data")
print("- Performance drops")
print("- Major search trend changes")
print("- New content categories")
# Out:
# Monitoring
# - Review model performance regularly.
# - Monitor search trends.
# - Track recommendation quality.
#
# Retrain Triggers
# - Large amount of new data
# - Performance drops
# - Major search trend changes
# - New content categories

# %% [markdown]
# ## 5. Exports for the paper
#
# *Write the queue (and any figures you want to reuse) to work/outputs/ — your paper builds on these files.*

# %% [markdown]
# ### Exports for the Paper
#
# This notebook exports a ranked content action queue that can be reused in the Week 8 research paper. The exported data is intended for demonstration purposes and supports the recommendations section of the capstone project.

# %%
import os

# Create output folder
os.makedirs("work/outputs", exist_ok=True)

# Export the ranked actions table
actions.to_csv("work/outputs/ranked_action_queue.csv", index=False)

print("Export completed successfully!")
print("File saved to: work/outputs/ranked_action_queue.csv")
# Out:
# Export completed successfully!
# File saved to: work/outputs/ranked_action_queue.csv

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
